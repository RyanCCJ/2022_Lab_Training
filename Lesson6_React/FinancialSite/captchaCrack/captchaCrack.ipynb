# %%
import os
import requests
from bs4 import BeautifulSoup
import ddddocr
from selenium import webdriver

# %%
ocr = ddddocr.DdddOcr()
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder

# %%
# driver = webdriver.Chrome("/home/cosbi/financialSite/captchaCrack/chromedriver")

options = webdriver.ChromeOptions()
options.add_argument('--headless')

driver = webdriver.Chrome(chrome_options = options, executable_path = "/home/cosbi/financialSite/captchaCrack/chromedriver")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      70             cmd.extend(self.command_line_args())
# ---> 71             self.process = subprocess.Popen(cmd, env=self.env,
#      72                                             close_fds=system() != 'Windows',
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ...

# %%
try:
    driver.get("https://bsr.twse.com.tw/bshtm/bsMenu.aspx")
    driver.refresh()
    
    imgPath = driver.find_elements_by_css_selector("img")[1].get_attribute("src")
    
    with open("temp.jpg", "wb") as f:
        f.write(requests.get(imgPath, verify = False).content)
        f.close()

    with open("temp.jpg", 'rb') as f:
        image = f.read()
        f.close()

    res = ocr.classification(image)
    
    driver.find_element_by_name("TextBox_Stkno").clear()
    driver.find_element_by_name("TextBox_Stkno").send_keys("0051")
    driver.find_element_by_name("CaptchaControl1").clear()
    driver.find_element_by_name("CaptchaControl1").send_keys(res)
    driver.find_element_by_name("btnOK").click()
    
    driver.get("https://bsr.twse.com.tw/bshtm/bsContent.aspx?v=t")
    soup = BeautifulSoup(driver.page_source, "html.parser")
    print(soup)

except Exception as e:
    print(e)
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml"><head><title>
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><link href="./BSR_Style.css" id="ssLayout" rel="stylesheet" type="text/css"/></head>
# <body bottommargin="0" leftmargin="0" rightmargin="0" topmargin="0">
# <form action="./bsContent.aspx?v=t" id="form1" method="post" name="form1">
# <div>
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwUKLTgxNDI2MzM4MGRkOCeVH5iuNhKRRTu7K+3m5A=="/>
# </div>
# <div>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="23969AED"/>
# </div>
# ...

# %%
driver.close()
